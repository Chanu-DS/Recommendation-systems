# %%
import pandas as pd
import numpy as np

# %%
movies_df=pd.read_csv(r'C:\Users\Chanukya Sai\Downloads\my data science\data sets (for practice only here)\tmdb_5000_movies.csv')
credits_df=pd.read_csv(r'C:\Users\Chanukya Sai\Downloads\my data science\data sets (for practice only here)\tmdb_5000_credits.csv')

# %%
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
print('movies df shape: \n',movies_df.shape,' \n','movie df columns:\n',movies_df.columns,'\n','credits df shape and columns:\n',credits_df.shape,credits_df.columns)
# Out:
# movies df shape:
#  (4803, 20)
#  movie df columns:
#  Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')
#  credits df shape and columns:
#  (4803, 4) Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
credits_df_renamedcolumn=credits_df.rename(index=str,columns={'movie_id':'id'})

# %%
movies_merge_df=movies_df.merge(credits_df_renamedcolumn,on='id')
movies_merge_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_merge_df.shape
# Out:
# (4803, 23)

# %%
movies_cleaned_df=movies_merge_df.drop(columns=['homepage','title_x','title_y','status','production_countries'])

# %%
movies_cleaned_df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %%
movies_cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   id                    4803 non-null   int64
#  3   keywords              4803 non-null   object
#  4   original_language     4803 non-null   object
#  5   original_title        4803 non-null   object
#  6   overview              4800 non-null   object
#  7   popularity            4803 non-null   float64
#  8   production_companies  4803 non-null   object
#  9   release_date          4802 non-null   object
#  10  revenue               4803 non-null   int64
#  11  runtime               4801 non-null   float64
#  12  spoken_languages      4803 non-null   object
#  13  tagline               3959 non-null   object
#  14  vote_average          4803 non-null   float64
# ...

# %% [markdown]
# #  using weighted average for each movie avg rating

# %% [markdown]
# ###  w= (rv+cm)/(v+m)
# ### v- votes r-avg rating c- total rating m-min votes required

# %%
v=movies_cleaned_df['vote_count']
r=movies_cleaned_df['vote_average']
c=movies_cleaned_df['vote_average'].mean()
m=movies_cleaned_df['vote_count'].quantile(0.70)

# %%
movies_cleaned_df['weighted_avg']=((r*v)+(c*m))/(v+m)

# %%
movies_cleaned_df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %%
movies_sorted_ratings_df=movies_cleaned_df.sort_values('weighted_avg',ascending=False)

# %%
movies_sorted_ratings_df[['original_title','popularity','weighted_avg','overview','revenue']]#.reset_index(drop=True, inplace=True)
# Out:
#                 original_title  popularity  weighted_avg  \
# 1881  The Shawshank Redemption  136.747729      8.340775
# 3337             The Godfather  143.659698      8.192887
# 662                 Fight Club  146.757391      8.171648
# 3232              Pulp Fiction  121.463076      8.157615
# 65             The Dark Knight  187.322927      8.102674
# ...                        ...         ...           ...
# 303                   Catwoman   32.271938      4.991470
# 3746         The Boy Next Door   24.161735      4.822053
# 210             Batman & Robin   50.073575      4.749951
# 242             Fantastic Four   38.126095      4.743880
# 1652      Dragonball Evolution   21.677732      4.678190
#
#                                                overview     revenue
# 1881  Framed in the 1940s for the double murder of h...    28341469
# 3337  Spanning the years 1945 to 1955, a chronicle o...   245066411
# 662   A ticking-time-bomb insomniac and a slippery s...   100853753
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies_sorted_ratings_df.dtypes
# Out:
# budget                    int64
# genres                   object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# tagline                  object
# vote_average            float64
# vote_count                int64
# cast                     object
# crew                     object
# weighted_avg            float64
# dtype: object

# %%
plt.figure(figsize=(12,6))
axis1=sns.barplot(x=movies_sorted_ratings_df['weighted_avg'].head(20),y=movies_sorted_ratings_df['original_title'].head(20),data=movies_sorted_ratings_df)
plt.xlim(4,10)
plt.title('Best movies based on weighted avg on avg ratings')
plt.xlabel('Weighted Average')
plt.ylabel('Top 20 movies ')
plt.savefig('top20 movies plot.png')
plt.show()

# %%
popularity=movies_sorted_ratings_df.sort_values('popularity',ascending=False)

# %%
popularity.head()
# Out:
#         budget                                             genres      id  \
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...  211672
# 95   165000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...  157336
# 788   58000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  293660
# 94   170000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...  118340
# 127  150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   76341
#
#                                               keywords original_language  \
# 546  [{"id": 3487, "name": "assistant"}, {"id": 179...                en
# 95   [{"id": 83, "name": "saving the world"}, {"id"...                en
# 788  [{"id": 2095, "name": "anti hero"}, {"id": 307...                en
# 94   [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 127  [{"id": 2964, "name": "future"}, {"id": 3713, ...                en
#
#               original_title  \
# 546                  Minions
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=popularity['popularity'].head(10),y=popularity['original_title'].head(10),data=popularity)
plt.title('popularity based movie top list')
plt.xlabel('Popularity')
plt.ylabel('Movies')
plt.show()
plt.savefig('popularity based movies')

# %% [markdown]
# # now wedo 50% on popularity and 50% on weighted avg

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaling=MinMaxScaler()

movies_scaled=scaling.fit_transform(movies_cleaned_df[['weighted_avg','popularity']])
movies_normalized=pd.DataFrame(movies_scaled,columns=['weighted_avg','popularity'])
movies_normalized.head(30)
# Out:
#     weighted_avg  popularity
# 0       0.674339    0.171815
# 1       0.581403    0.158846
# 2       0.436273    0.122635
# 3       0.773054    0.128272
# 4       0.387739    0.050169
# 5       0.340926    0.132141
# 6       0.690093    0.055600
# 7       0.689761    0.153360
# 8       0.707820    0.112937
# 9       0.287188    0.177928
# 10      0.252503    0.066157
# 11      0.387848    0.123265
# 12      0.609212    0.166572
# 13      0.344133    0.056016
# 14      0.488089    0.113522
# 15      0.427894    0.061649
# 16      0.726350    0.164975
# 17      0.461276    0.154656
# 18      0.411894    0.059429
# 19      0.631297    0.138155
# 20      0.488384    0.102636
# 21      0.406858    0.043021
# 22      0.750892    0.107780
# 23      0.330890    0.049100
# 24      0.497107    0.069926
# 25      0.743017    0.114239
# 26      0.640791    0.226561
# 27      0.259236    0.074155
# 28      0.490412    0.478206
# 29      0.590967    0.106221

# %%
movies_cleaned_df[['normalized_weighted_avg','normalized_popularity']]=movies_normalized
movies_cleaned_df.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# ...

# %%
movies_cleaned_df['score']=movies_cleaned_df['normalized_weighted_avg']*0.5+movies_cleaned_df['normalized_popularity']*0.5
final_recommendation=movies_cleaned_df[['original_title','normalized_weighted_avg','normalized_popularity','score']].sort_values('score',ascending=False)

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=final_recommendation['score'].head(10),y=final_recommendation['original_title'].head(10),data=final_recommendation)
plt.title('Movie recommendation weighted avg--popularity')
plt.xlabel('score',weight='bold')
plt.ylabel('Movies')
plt.show()
plt.savefig('Votes_avg and popularity top movies list')

# %% [markdown]
# # this is so basic recommendation
